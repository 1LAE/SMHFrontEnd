# %% [markdown]
# # Правки и исправления

# %% [markdown]
# 1. Сделать для мест в контейнерах отдельные функции для изменения состояния
# 2. В каждой из вкладок поп-апов работы с контейнерами сделать функции для изменения состояния
# 3. Сделать родителььский класс / функцию для управления столом, который бы обрабатывал запросы от поп-апов и говорил что где менять
# и отправлял бы информацию элементам состояние соответствующих контейнеров
# 4. Возможно переписать все на классы
# 5.
